# %% [markdown]
# >💡 **Динамическое программирование** — это подход, при котором исходная задача разбивается на несколько мелких. Работа начинается с решения одной подзадачи, потом решается следующая, крупнее — и в каждой следующей подзадаче применяется решение предыдущей.
#
# Описание принципа динамического программирования чем-то сходно с описанием рекурсии, однако есть принципиальное различие:
#
# * при рекурсивном подходе «точкой отправления» служит исходная задача, именно с неё начинается поиск решения;
#
# * при динамическом программировании поиск решения начинается **с первой подзадачи**, а не с полного условия исходной задачи.

# %% [markdown]
# ... у меня нет слов...
