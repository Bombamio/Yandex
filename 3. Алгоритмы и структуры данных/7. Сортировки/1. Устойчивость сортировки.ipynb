# %% [markdown]
# Если после применения сортировки первоначальный порядок элементов с равными значениями сохраняется, такая сортировка называется **устойчивой** или **стабильной** (англ. stable sort). Если же при сортировке элементы с равными значениями могут поменяться местами, сортировку называют **неустойчивой** или **нестабильной**.
#
# Как правило, устойчивость сортировки важна там, где элементы в исходном массиве уже упорядочены по какому-то признаку: в примере с вольерами в исходном массиве задан порядок кормления тигров, и этот порядок необходимо сохранить после сортировки.
#
# ***
# ## Устойчивость сортировок
#
# >💡 Когда говорят про устойчивость сортировки, употребляют словосочетание «относительный порядок элементов `n1` и `n2` сохранился». Это значит, что если в исходном массиве элемент `n1` расположен раньше, чем равный ему элемент `n2`, то и после сортировки `n1` будет стоять раньше `n2`: они сохранили порядок размещения друг относительно друга.
